# %%
import pandas as pd
import os

# %%
person = [['人名1','性别1', '身高1'],
         ['人名2','性别2', '身高2'],
         ['人名3','性别3', '身高3'],
         ['人名4','性别4', '身高4']]

# %%
df = pd.DataFrame(person, columns = ['Name', 'Sex', 'Height'])

# %%
df
# Out:
#   Name  Sex Height
# 0  人名1  性别1    身高1
# 1  人名2  性别2    身高2
# 2  人名3  性别3    身高3
# 3  人名4  性别4    身高4

# %%
df.to_csv('person.csv')

# %%
from IPython.display import Image
Image(filename='person_csv_screenshot.png', width=400, height=300)

# %%
df.to_csv('person2.csv', encoding='utf_8_sig')

# %%
Image(filename='person2_screenshot.png', width=400, height=300)
